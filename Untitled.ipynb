# %%
import pandas as pd
import matplotlib as mptl
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('out_dya1.csv',sep=';')
df2 = pd.read_csv ('out_dya2.csv',sep=';')
df3 = pd.read_csv ('out_dya3.csv',sep=';')
df4 = pd.read_csv ('out_dya4.csv',sep=';')
df5 = pd.read_csv ('out_dya5.csv',sep=';')
df = df.append(df2,ignore_index=True)
df = df.append(df3,ignore_index=True)
df = df.append(df4,ignore_index=True)
df = df.append(df5,ignore_index=True)

df.to_csv('out_all.csv', sep=';', encoding='utf-8')
df
# Out:
#           id  epoch  svs           Ispb           Vtec          Vtec2  \
# 0        182    600  G27  457604.628216  480788.499096  441426.416548
# 1        192    630  G27  395645.266045  415690.056234  381657.573472
# 2        202    660  G27  271536.190684  285293.175635  261936.265994
# 3        212    690  G27  324834.566928  341291.836353  313350.324731
# 4        222    720  G27  301992.405579  317292.410225  291315.728032
# ...      ...    ...  ...            ...            ...            ...
# 27140  26195  86640  G27  313603.837627  329492.118538  302516.648049
# 27141  26205  86670  G27  293045.892414  307892.635022  282685.511020
# 27142  26213  86700  G27  321122.715310  337391.929188  309769.702382
# 27143  26222  86730  G27  410683.022119  431489.678280  396163.682823
# 27144  26230  86760  G27  352054.808463  369891.151714  339608.218418
#
#                Vtec3
# 0      196101.170502
# 1      169549.202501
# 2      116363.693773
# 3      139204.096432
# ...

# %%
#df[sorted(df.epoch)]
df.plot.scatter(x='epoch',y='Vtec',c='DarkBlue')
